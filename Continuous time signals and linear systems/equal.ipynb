# %%
from sympy import *
s, t, omega, n = symbols("s t omega n", real=True)
R1, R2, C1, C2, L1, L2 = symbols("R1 R2 C1 C2 L1 L2", positive=True, real=True)
VA, VB, V1 = symbols("VA VB V1")

n =2

num_a = 8*(-t + exp(t) - 1)*exp(-4*t)*Heaviside(t)
den_a = 1

num_b =(-8*t*exp(-4 * t) - 8 *exp(-4*t)+ 8*exp(-3*t))*Heaviside(t)
den_b =1


a = num_a / den_a
b = num_b / den_b

print("a")
display(num_a, den_a,)
print("b")
display(num_b, den_b)

a = a.normal()
a = a.simplify()
a = a.expand()

b = b.normal()
b = b.simplify()
b = b.expand()

equal = a == b

print("equal?")
display(equal)

a
# Out:
# a
# (-8*t + 8*exp(t) - 8)*exp(-4*t)*Heaviside(t)
# 1
# b
# (-8*t*exp(-4*t) + 8*exp(-3*t) - 8*exp(-4*t))*Heaviside(t)
# 1
# equal?
# True
# -8*t*exp(-4*t)*Heaviside(t) + 8*exp(-3*t)*Heaviside(t) - 8*exp(-4*t)*Heaviside(t)
